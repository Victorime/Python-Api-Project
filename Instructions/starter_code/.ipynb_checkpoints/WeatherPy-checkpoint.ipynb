# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %%
#query_url = f"{url}appid={weather_api_key}&units={units}&q="
#response = requests.get(query_url).json()
#pprint(response)

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL

query_url = f"{url}appid={weather_api_key}&units={units}&q="



for index, city in np.ndenumerate(cities):
    print(index[0],": ", city)
# Out:
# 0 :  puerto ayora
# 1 :  barrow
# 2 :  doraville
# 3 :  cassilandia
# 4 :  albany
# 5 :  kaitangata
# 6 :  jamestown
# 7 :  sao joao da barra
# 8 :  araouane
# 9 :  kapaa
# 10 :  flinders
# 11 :  bandarbeyla
# 12 :  ushuaia
# 13 :  dembi dolo
# 14 :  alexandria
# 15 :  kununurra
# 16 :  hobart
# 17 :  punta arenas
# 18 :  hilo
# 19 :  deer lake
# 20 :  bredasdorp
# 21 :  saldanha
# 22 :  grindavik
# 23 :  qaanaaq
# 24 :  trairi
# 25 :  road town
# 26 :  georgetown
# 27 :  illoqqortoormiut
# 28 :  chokurdakh
# 29 :  bluff
# 30 :  busselton
# 31 :  mataura
# 32 :  castro
# 33 :  batagay-alyta
# 34 :  temir
# 35 :  thompson
# 36 :  nanzhou
# 37 :  isangel
# 38 :  rikitea
# 39 :  uwayl
# 40 :  hithadhoo
# 41 :  point pedro
# 42 :  clyde river
# 43 :  east london
# 44 :  sorland
# 45 :  atuona
# 46 :  vila velha
# 47 :  arraial do cabo
# 48 :  atar
# 49 :  rajshahi
# 50 :  westport
# 51 :  bur gabo
# 52 :  noumea
# 53 :  ponazyrevo
# 54 :  jining
# 55 :  klaksvik
# 56 :  coquimbo
# 57 :  tlaxiaco
# 58 :  torbay
# 59 :  saint-philippe
# 60 :  new norfolk
# 61 :  port-cartier
# 62 :  taltal
# 63 :  talakan
# 64 :  port alfred
# 65 :  madera
# 66 :  dikson
# 67 :  longyearbyen
# 68 :  gilbues
# 69 :  altagracia de orituco
# 70 :  ribeira grande
# 71 :  muros
# 72 :  butaritari
# 73 :  bodden town
# 74 :  leningradskiy
# 75 :  sentyabrskiy
# 76 :  tasiilaq
# 77 :  tuktoyaktuk
# 78 :  nanortalik
# 79 :  port lincoln
# 80 :  saskylakh
# 81 :  shakawe
# 82 :  bibiani
# 83 :  taolanaro
# 84 :  vega de alatorre
# 85 :  norman wells
# 86 :  lolua
# 87 :  sain alto
# 88 :  victoria
# 89 :  luau
# 90 :  mys shmidta
# 91 :  outlook
# 92 :  sikeston
# 93 :  wajima
# 94 :  lubu
# 95 :  tsihombe
# 96 :  bathurst
# 97 :  shahrud
# 98 :  vila franca do campo
# 99 :  isetskoye
# 100 :  harbour breton
# 101 :  kavieng
# 102 :  pangnirtung
# 103 :  khatanga
# 104 :  mount gambier
# 105 :  bambous virieux
# 106 :  maniitsoq
# 107 :  itarema
# 108 :  arrifes
# 109 :  ilulissat
# 110 :  vao
# 111 :  sawtell
# 112 :  kruisfontein
# 113 :  tual
# 114 :  katsiveli
# 115 :  bengkulu
# 116 :  kendari
# 248 :  sri aman
# 249 :  maragogi
# 250 :  stornoway
# 251 :  tumannyy
# 252 :  mecca
# 253 :  farafangana
# 254 :  gat
# 255 :  ponta do sol
# 256 :  sao felix do xingu
# 257 :  anadyr
# 258 :  coihaique
# 259 :  fairbanks
# 260 :  macroom
# 261 :  guinsiliban
# 262 :  karoi
# 263 :  caravelas
# 264 :  mana
# 265 :  smithers
# 266 :  bridgetown
# 267 :  dzaoudzi
# 268 :  rodez
# 269 :  deseronto
# 270 :  los llanos de aridane
# 271 :  pokrovsk
# 272 :  upernavik
# 273 :  satipo
# 274 :  akdepe
# 275 :  ahipara
# 276 :  carrickmacross
# 277 :  zalari
# 278 :  sitka
# 279 :  carayao
# 280 :  tasbuget
# 281 :  lodwar
# 282 :  bilma
# 283 :  comodoro rivadavia
# 284 :  mundo nuevo
# 285 :  srednekolymsk
# 286 :  greenlaw
# 287 :  mergui
# 288 :  baykit
# 289 :  vaitupu
# 290 :  merauke
# 291 :  altay
# 292 :  bristol
# 293 :  kamaishi
# 294 :  alghero
# 295 :  kropotkin
# 296 :  kudahuvadhoo
# 297 :  bethel
# 298 :  belaya gora
# 299 :  bani
# 300 :  guangyuan
# 301 :  kasongo-lunda
# 302 :  mareeba
# 303 :  tiksi
# 304 :  saint-joseph
# 305 :  mpulungu
# 306 :  myre
# 307 :  matay
# 308 :  rossland
# 309 :  pinawa
# 310 :  tabou
# 311 :  muisne
# 312 :  galesong
# 313 :  shelburne
# 314 :  ugoofaaru
# 315 :  mount isa
# 316 :  otukpo
# 317 :  nome
# 318 :  cherskiy
# 319 :  dzhusaly
# 320 :  gornopravdinsk
# 321 :  grand river south east
# 322 :  bilibino
# 323 :  paredon
# 324 :  clarence town
# 325 :  chinsali
# 326 :  acapulco
# 327 :  arman
# 328 :  son la
# 329 :  asau
# 330 :  geraldton
# 331 :  atasu
# 332 :  puro
# 333 :  provideniya
# 334 :  cabo san lucas
# 335 :  uvat
# 336 :  rincon
# 337 :  asosa
# 338 :  garowe
# 339 :  half moon bay
# 340 :  miraflores
# 341 :  sobolevo
# 342 :  kailua
# 343 :  severo-kurilsk
# 344 :  henties bay
# 345 :  harper
# 346 :  halalo
# 347 :  banjar
# 348 :  codrington
# 349 :  portland
# 350 :  lom sak
# 351 :  constitucion
# 352 :  vladyslavivka
# 353 :  luderitz
# 354 :  karaul
# 355 :  linjiang
# 356 :  sao filipe
# 357 :  sao sepe
# 358 :  rapid city
# 359 :  lufilufi
# 360 :  adelaide
# 361 :  brandon
# 362 :  marawi
# 363 :  el doncello
# 364 :  sola
# 365 :  cidreira
# 366 :  micheweni
# 367 :  kastamonu
# 368 :  eureka
# 369 :  san quintin
# 370 :  gravdal
# 371 :  high level
# 372 :  bourges
# 373 :  tommot
# 374 :  palauig
# 375 :  oussouye
# 376 :  ilo
# 377 :  hoquiam
# 378 :  soyo
# 379 :  kirakira
# 510 :  berbera
# 511 :  samusu
# 512 :  vestmanna
# 513 :  lebanon
# 514 :  parabel
# 515 :  san andres
# 516 :  jaysingpur
# 517 :  ust-nera
# 518 :  ruwi
# 519 :  opuwo
# 520 :  sorrento
# 521 :  dandong
# 522 :  avera
# 523 :  dogondoutchi
# 524 :  komsomolskiy
# 525 :  mosquera
# 526 :  biancavilla
# 527 :  coffs harbour
# 528 :  vanimo
# 529 :  lusambo
# 530 :  lafiagi
# 531 :  ushumun
# 532 :  ternate
# 533 :  mayo
# 534 :  caetes
# 535 :  wanning
# 536 :  katangli
# 537 :  samarkand
# 538 :  san carlos
# 539 :  solano
# 540 :  pochutla
# 541 :  belushya guba
# 542 :  sakakah
# 543 :  mettur
# 544 :  okakarara
# 545 :  elbistan
# 546 :  safwah
# 547 :  rio gallegos
# 548 :  whitehorse
# 549 :  kathmandu
# 550 :  ponta delgada
# 551 :  aksu
# 552 :  gigmoto
# 553 :  najran
# 554 :  santa rosa
# 555 :  khanpur
# 556 :  christchurch
# 557 :  nguiu
# 558 :  coronado
# 559 :  sabang
# 560 :  nelson bay
# 561 :  porto novo
# 562 :  bonnyville
# 563 :  pipri
# 564 :  kpandu
# 565 :  beyla
# 566 :  urdoma
# 567 :  datong
# 568 :  pacific grove
# 569 :  husavik
# 570 :  rayachoti
# 571 :  tura
# 572 :  laurel
# 573 :  banda aceh
# 574 :  requena
# 575 :  evensk
# 576 :  manicore
# 577 :  mungwi
# 578 :  bargal
# 579 :  marcona
# 580 :  luganville
# 581 :  ust-kamchatsk
# 582 :  west bay
# 583 :  bahir dar
# 584 :  magdagachi
# 585 :  malinyi
# 586 :  mosetse
# 587 :  lagos
# 588 :  ashland
# 589 :  sulangan
# 590 :  mujiayingzi
# 591 :  dossor
# 592 :  pahrump
# 593 :  ancud
# 594 :  magdiwang
# 595 :  padang
# 596 :  quatre cocos
# 597 :  port-gentil
# 598 :  zhuanghe
# 599 :  union
# 600 :  dinsor
# 601 :  la ronge
# 602 :  jiuquan
# 603 :  marfino
# 604 :  san pedro de macoris

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Creating an empty list 

city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Loop through the list of cities and request the weather for each

for city in cities:
        response = requests.get(query_url + city).json() 
        try:
            city_name.append(response['name'])
            cloudiness.append(response['clouds']['all'])
            country.append(response['sys']['country'])
            date.append(response['dt'])
            humidity.append(response['main']['humidity'])
            max_temp.append(response['main']['temp_max'])
            lat.append(response['coord']['lat'])
            lng.append(response['coord']['lon'])
            wind_speed.append(response['wind']['speed'])
            print(f"{city} City Found") 
        except:
            print(f"{city} not found.")
            pass
# Out:
# puerto ayora City Found
# barrow City Found
# doraville City Found
# cassilandia City Found
# albany City Found
# kaitangata City Found
# jamestown City Found
# sao joao da barra City Found
# araouane City Found
# kapaa City Found
# flinders City Found
# bandarbeyla City Found
# ushuaia City Found
# dembi dolo City Found
# alexandria City Found
# kununurra City Found
# hobart City Found
# dire dawa City Found
# huarmey City Found
# qarchi gak City Found
# souillac City Found
# tulun City Found
# mackay City Found
# raga City Found
# richards bay City Found
# port blair City Found
# kapoeta City Found
# lere City Found
# ulaangom City Found
# almaznyy City Found
# pingzhuang City Found
# lobito City Found
# bandar-e anzali City Found
# berbera City Found
# samusu not found.
# vestmanna City Found
# lebanon City Found
# parabel City Found
# san andres City Found
# jaysingpur City Found
# ust-nera City Found
# ruwi City Found
# opuwo City Found
# sorrento City Found
# dandong City Found
# avera City Found
# dogondoutchi City Found
# komsomolskiy City Found
# mosquera City Found
# biancavilla City Found
# coffs harbour City Found
# vanimo City Found
# lusambo City Found
# lafiagi City Found
# ushumun City Found
# ternate City Found
# mayo City Found
# caetes City Found
# wanning City Found
# katangli City Found
# samarkand City Found
# san carlos City Found
# solano City Found
# pochutla City Found
# belushya guba not found.
# sakakah City Found
# mettur City Found
# okakarara City Found
# elbistan City Found
# safwah not found.
# rio gallegos City Found
# whitehorse City Found
# kathmandu City Found
# ponta delgada City Found
# aksu City Found
# gigmoto City Found
# najran City Found
# santa rosa City Found
# khanpur City Found
# christchurch City Found
# nguiu not found.
# coronado City Found
# sabang City Found
# nelson bay City Found
# porto novo City Found
# bonnyville City Found
# pipri City Found
# kpandu City Found
# beyla City Found
# urdoma City Found
# datong City Found
# pacific grove City Found
# husavik City Found
# rayachoti City Found
# tura City Found
# laurel City Found
# banda aceh City Found
# requena City Found
# evensk City Found
# manicore City Found
# mungwi City Found
# bargal not found.
# marcona not found.
# luganville City Found
# ust-kamchatsk not found.
# west bay City Found
# bahir dar City Found
# magdagachi City Found
# malinyi City Found
# mosetse City Found
# lagos City Found
# ashland City Found
# sulangan City Found
# mujiayingzi City Found
# dossor City Found
# pahrump City Found
# ancud City Found
# magdiwang City Found
# padang City Found
# quatre cocos City Found
# port-gentil City Found
# zhuanghe City Found
# union City Found
# dinsor not found.
# la ronge City Found
# jiuquan City Found
# marfino City Found
# san pedro de macoris City Found

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
dict_weather = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
city_data = pd.DataFrame(dict_weather)

city_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Puerto Ayora          20      EC  1580224641        69  -0.74  -90.35
# 1        Barrow          75      US  1580224640        74  71.29 -156.79
# 2     Doraville           1      US  1580224795        70  33.90  -84.28
# 3   Cassilandia           0      BR  1580224795        62 -19.11  -51.73
# 4        Albany          75      US  1580224637        59  42.60  -73.97
#
#    Max Temp  Wind Speed
# 0     80.60        2.24
# 1    -25.60        3.36
# 2     48.99        4.70
# 3     84.36        7.45
# 4     37.00       17.22

# %%
city_data.count()
# Out:
# City          556
# Cloudiness    556
# Country       556
# Date          556
# Humidity      556
# Lat           556
# Lng           556
# Max Temp      556
# Wind Speed    556
# dtype: int64

# %%
# Export the city data into a .csv
city_data.to_csv("city_data.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
today = time.strftime("%m/%d/%y")
# Build a scatter plot for each data type
plt.scatter(city_data["Lat"], city_data["Max Temp"], marker="o", color='b', alpha=0.5)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.xlim(-50,100)
plt.ylim(-40,100)

plt.grid()
plt.show()
print(f"This graph demonstrates the correlation that as we move away from the equator the temperature drop rapidly")
# Out:
# This graph demonstrates the correlation that as we move away from the equator the temperature drop rapidly

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_data["Lat"], city_data["Humidity"], marker="o",color='blue', alpha=0.5)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.xlim(-50,100)
plt.ylim(-50,100)
plt.grid()

plt.show()
print(f"This graph shows that there is no significant correlation between these two factors")


# Show plot
plt.show()
# Out:
# This graph shows that there is no significant correlation between these two factors

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_data["Lat"], city_data["Cloudiness"], marker="o",color='blue', alpha=0.5)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.xlim(-50,100)
plt.ylim(-40,100)
plt.grid() 

plt.show()
print(f"This graph shows there is no significant correlation between these two factors")

# Show plot
plt.show()
# Out:
# This graph shows there is no significant correlation between these two factors

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_data["Lat"], city_data["Wind Speed"], marker="o", color='blue', alpha=0.5)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed ")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.xlim(-50,100)
plt.ylim(-40,100)
plt.grid()

plt.show()
print(f"There is no significant correlation between thes two factors")


# Show plot
plt.show()
# Out:
# There is no significant correlation between thes two factors

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = city_data.loc[city_data["Lat"] > 0,:]
southern_df = city_data.loc[city_data["Lat"] < 0,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel(f'Max Temp (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# The r-squared is: -0.9018067183396887

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel(f'Max Temp (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# The r-squared is: 0.6270462824262001

# %%
print(f"The comparrison of the temperatures within the northern and sothern hemisphere's against latitude demonstrates that the temperature in creases as you approach the equator")
# Out:
# The comparrison of the temperatures within the northern and sothern hemisphere's against latitude demonstrates that the temperature in creases as you approach the equator

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel(f'Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# The r-squared is: 0.4682597951153488

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel(f'Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# The r-squared is: 0.12800423516831838

# %%
print(f"There was no notable relatoionship between humidity and latitude that can be identified")
# Out:
# There was no notable relatoionship between humidity and latitude that can be identified

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel(f'Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# The r-squared is: 0.24259867488134157

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel(f'Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# The r-squared is: 0.1846065939629529

# %%
print(f"There was not a notable relatoionship between cloudiness and latitude that was identified")
# Out:
# There was not a notable relatoionship between cloudiness and latitude that was identified

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel(f'Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# The r-squared is: 0.06108361612819231

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel(f'Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")

plt.show()
# Out:
# The r-squared is: -0.39730517521371417

# %%
print(f"There was no notable correlation from the north and southern Hemiphere on the Wind speed and Latitude plot that was noticeable")
# Out:
# There was no notable correlation from the north and southern Hemiphere on the Wind speed and Latitude plot that was noticeable
